# %%
import sys
# !conda install --yes --prefix {sys.prefix} nltk
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import nltk
import ssl
if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
from nltk.corpus import stopwords
print(stopwords.words("english")[:10])
from nltk.sentiment.vader import SentimentIntensityAnalyzer
s = SentimentIntensityAnalyzer() # en inglés hasta podemos distinguir entre palabras positivas y negativas
print(s.polarity_scores('useless'))
print(s.polarity_scores('marvelous'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USUARIO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USUARIO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USUARIO\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline
wr = pd.read_csv("/Users/USUARIO/Documents/GitHub/winemag-data_first150k.csv")
wr
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 11 columns]

# %%
review= ['country', 'description', 'variety']
wr.to_csv('winereviews.csv', columns = review)
wine= pd.read_csv('winereviews.csv')
wine
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                    variety
# 0       Cabernet Sauvignon
# 1            Tinta de Toro
# 2          Sauvignon Blanc
# 3               Pinot Noir
# 4       Provence red blend
# ...                    ...
# 150925         White Blend
# 150926     Champagne Blend
# 150927         White Blend
# 150928     Champagne Blend
# 150929        Pinot Grigio
#
# [150930 rows x 4 columns]

# %%
wine.drop(wine.columns[[0]], axis=1, inplace=True)
wine
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                    variety
# 0       Cabernet Sauvignon
# 1            Tinta de Toro
# 2          Sauvignon Blanc
# 3               Pinot Noir
# 4       Provence red blend
# ...                    ...
# 150925         White Blend
# 150926     Champagne Blend
# 150927         White Blend
# 150928     Champagne Blend
# 150929        Pinot Grigio
#
# [150930 rows x 3 columns]

# %%
wine['country'].unique()
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %%
wine.to_csv('wr.csv', index=False)
read = pd.read_csv('wr.csv')
read
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                    variety
# 0       Cabernet Sauvignon
# 1            Tinta de Toro
# 2          Sauvignon Blanc
# 3               Pinot Noir
# 4       Provence red blend
# ...                    ...
# 150925         White Blend
# 150926     Champagne Blend
# 150927         White Blend
# 150928     Champagne Blend
# 150929        Pinot Grigio
#
# [150930 rows x 3 columns]

# %%
import ssl
import pandas as pd
import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context
wr1= pd.read_csv('/Users/USUARIO/Documents/GitHub/solo-rev.csv', header = None)
wr1
# Out:
#                                                         0       1  \
# 0       This tremendous 100% varietal wine hails from ...      US
# 1       Ripe aromas of fig, blackberry and cassis are ...   Spain
# 2       Mac Watson honors the memory of a wine once ma...      US
# 3       This spent 20 months in 30% new French oak, an...      US
# 4       This is the top wine from La Bégude, named aft...  France
# ...                                                   ...     ...
# 150925  Many people feel Fiano represents southern Ita...   Italy
# 150926  Offers an intriguing nose with ginger, lime an...  France
# 150927  This classic example comes from a cru vineyard...   Italy
# 150928  A perfect salmon shade, with scents of peaches...  France
# 150929  More Pinot Grigios should taste like this. A r...   Italy
#
#                          2
# 0       Cabernet Sauvignon
# 1            Tinta de Toro
# 2          Sauvignon Blanc
# 3               Pinot Noir
# 4       Provence red blend
# ...                    ...
# 150925         White Blend
# 150926     Champagne Blend
# 150927         White Blend
# 150928     Champagne Blend
# 150929        Pinot Grigio
#
# [150930 rows x 3 columns]

# %%
wr1.columns = ['description','country','variety']
wr1
# Out:
#                                               description country  \
# 0       This tremendous 100% varietal wine hails from ...      US
# 1       Ripe aromas of fig, blackberry and cassis are ...   Spain
# 2       Mac Watson honors the memory of a wine once ma...      US
# 3       This spent 20 months in 30% new French oak, an...      US
# 4       This is the top wine from La Bégude, named aft...  France
# ...                                                   ...     ...
# 150925  Many people feel Fiano represents southern Ita...   Italy
# 150926  Offers an intriguing nose with ginger, lime an...  France
# 150927  This classic example comes from a cru vineyard...   Italy
# 150928  A perfect salmon shade, with scents of peaches...  France
# 150929  More Pinot Grigios should taste like this. A r...   Italy
#
#                    variety
# 0       Cabernet Sauvignon
# 1            Tinta de Toro
# 2          Sauvignon Blanc
# 3               Pinot Noir
# 4       Provence red blend
# ...                    ...
# 150925         White Blend
# 150926     Champagne Blend
# 150927         White Blend
# 150928     Champagne Blend
# 150929        Pinot Grigio
#
# [150930 rows x 3 columns]

# %%
n = len(wr1)
spa = stopwords.words("english")
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+') # para eliminar puntuación
reemplazos = []
for r in range(n):
    original = wr1.description[r]
    reemplazo = ''
    if original != 'NaN':
        quedar = [stemmer.stem(p) for p in tokenizer.tokenize(original) if p.lower() not in spa]
        reemplazo = ' '.join(quedar)
    reemplazos.append(reemplazo)
wr1['limpios'] = reemplazos
texto = ' '.join(reemplazos)
nube = WordCloud().generate(texto)
plt.rcParams["figure.figsize"] = [15, 7]
plt.imshow(nube)
plt.axis("off")
plt.show()

# %%
header = ['description','country','variety']
writer = wr1[wr1['country'] == 'US']
writer.to_csv('us-wine.csv', columns = header, index=False)
lol=pd.read_csv('us-wine.csv')
lol
# Out:
#                                              description country  \
# 0      This tremendous 100% varietal wine hails from ...      US
# 1      Mac Watson honors the memory of a wine once ma...      US
# 2      This spent 20 months in 30% new French oak, an...      US
# 3      This re-named vineyard was formerly bottled as...      US
# 4      The producer sources from two blocks of the vi...      US
# ...                                                  ...     ...
# 62392  A light, earthy wine, with violet, berry and t...      US
# 62393  Some raspberry fruit in the aroma, but things ...      US
# 62394  Old-gold in color, and thick and syrupy. The a...      US
# 62395  Decades ago, Beringer’s then-winemaker Myron N...      US
# 62396  An impressive wine that presents a full bouque...      US
#
#                   variety
# 0      Cabernet Sauvignon
# 1         Sauvignon Blanc
# 2              Pinot Noir
# 3              Pinot Noir
# 4              Pinot Noir
# ...                   ...
# 62392              Merlot
# 62393          Pinot Noir
# 62394      White Riesling
# 62395         White Blend
# 62396     Champagne Blend
#
# [62397 rows x 3 columns]

# %%
header = ['description','country','variety']
writer = wr[wr1['country'] == 'Italy']
writer.to_csv('italy-wine.csv', columns = header, index=False)
lol = pd.read_csv('italy-wine.csv')
lol
# Out:
#                                              description country  \
# 0      Elegance, complexity and structure come togeth...   Italy
# 1      Underbrush, scorched earth, menthol and plum s...   Italy
# 2      Forest floor, tilled soil, mature berry and a ...   Italy
# 3      Aromas of forest floor, violet, red berry and ...   Italy
# 4      This has a charming nose that boasts rose, vio...   Italy
# ...                                                  ...     ...
# 23473  Rich and mature aromas of smoke, earth and her...   Italy
# 23474  Made by 30-ish Roberta Borghese high above Man...   Italy
# 23475  Many people feel Fiano represents southern Ita...   Italy
# 23476  This classic example comes from a cru vineyard...   Italy
# 23477  More Pinot Grigios should taste like this. A r...   Italy
#
#                variety
# 0             Friulano
# 1           Sangiovese
# 2           Sangiovese
# 3           Sangiovese
# 4           Sangiovese
# ...                ...
# 23473  Champagne Blend
# 23474            Tocai
# 23475      White Blend
# 23476      White Blend
# 23477     Pinot Grigio
#
# [23478 rows x 3 columns]

# %%
header = ['description','country','variety']
writer = wr1[wr1['country'] == 'Portugal']
writer.to_csv('portugal-wine.csv', columns = header, index=False)
lol= pd.read_csv('portugal-wine.csv')
lol
# Out:
#                                             description   country  \
# 0     This is a super-ripe, still very young wine. I...  Portugal
# 1     It is the ripe dark Alicante Bouschet that dom...  Portugal
# 2     The local Baga grape, better known for produci...  Portugal
# 3     This family-owned estate has produced an immed...  Portugal
# 4     This state-owned estate of forests and vineyar...  Portugal
# ...                                                 ...       ...
# 5317  An easy, fresh, ripe style, with dried fruits ...  Portugal
# 5318  This is a very old 40-year old, with some hars...  Portugal
# 5319  Oreo eaters will enjoy the aromas of this wine...  Portugal
# 5320  A powerful, solid wine, packed with luscious f...  Portugal
# 5321  This wine has the dark fruit typical of this q...  Portugal
#
#              variety
# 0     Portuguese Red
# 1     Portuguese Red
# 2               Baga
# 3     Portuguese Red
# 4     Portuguese Red
# ...              ...
# 5317            Port
# 5318            Port
# 5319            Port
# 5320            Port
# 5321            Port
#
# [5322 rows x 3 columns]

# %%
import ssl
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer

if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context
dini = pd.read_csv("portugal-wine.csv", header = None)
dmcu = pd.read_csv("us-wine.csv", header = None)
dord = pd.read_csv("italy-wine.csv", header = None)
cols = ['description', 'country', 'variety']
dini.columns = cols
dmcu.columns = cols
dord.columns = cols
spa = stopwords.words("english")
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+') # para eliminar puntuación
plt.rcParams["figure.figsize"] = [18, 9]
f = plt.figure() 
lbls = ["Portugal", "US", "Italia"]
i = 1
for d in [dini, dmcu, dord]:
    lbl = lbls.pop(0)
    reemplazos = []
    for r in range(len(d)):
        original = d.description[r]
        reemplazo = ''
        if original != 'NaN':
            quedar = [stemmer.stem(p) for p in tokenizer.tokenize(original) if p.lower() not in spa]
            reemplazo = ' '.join(quedar)
        reemplazos.append(reemplazo)
    d['limpios'] = reemplazos
    for tipo in lbls:
        sf = plt.subplot(3, 3, i)
        i += 1
        texto = ' '.join(reemplazos)
        sf.set_title(tipo)
        nube = WordCloud().generate(texto)
        sf.imshow(nube)
        sf.axis("off")
plt.tight_layout()
plt.show()

# %%
import sys
# !{sys.executable} -m pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in c:\users\usuario\anaconda3\lib\site-packages (0.5.4)

# %%
import ssl
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
from spellchecker import SpellChecker
sc = SpellChecker()
adicionales = [ 'ready', 'texture']
if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context
d = pd.read_csv("portugal-wine.csv", header = None)
d.columns = ['description', 'country', 'variety']
spa = stopwords.words("english") 
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+') # para eliminar puntuación
plt.rcParams["figure.figsize"] = [12, 6]
texto = ''
for original in d.description:
    palabras = tokenizer.tokenize(original)
    revisadas = []
    for p in sc.known(palabras):
        revisadas += [p] * palabras.count(p) # para no alterar las frecuencias       
    for p in sc.unknown(palabras):
         revisadas += [sc.correction(p)] * palabras.count(p)
    inicial = [stemmer.stem(p) for p in revisadas if p.lower() not in spa]
    quedar = [p for p in inicial if p not in adicionales]
    texto += ' '.join(quedar) + ' '
plt.title('')
nube = WordCloud().generate(texto)
plt.imshow(nube)
plt.axis("off")
plt.show()
